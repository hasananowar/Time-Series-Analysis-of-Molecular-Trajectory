# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import math
# from ipynb.fs.full.utils import split_xyz, distance_periodicity

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\mhanowar\Box\Iowa State Research\Shared Materials_Abdullah_Hasan\Abdullah Data\nov 2022 ring ring\ring ring november\SFL11\m1m11r27r1.csv", delimiter= ',')
Dist = np.array(data['Distance'])
Y = np.array(data['Angle'])
# Angle  = np.array([180-y if y>90 else y for y in Y])
# Angle
# Out:
# array([72.67755022, 86.12522651, 79.02130855, ..., 59.37356462,
#        55.38672878, 49.49881982])

# %%
# 255K-256K
plt.scatter(Dist [55000:55100], Y[55000:55100])
plt.show()

# %%
# 259.3K-260K
plt.scatter( Dist [59300:60000],Y[59300:60000])
plt.show()

# %%
# x_coord_diff = (72.475-abs(atom2[0] - atom1[0])) if abs(atom2[0] - atom1[0])>36.2375 else (atom2[0] - atom1[0])
    
# y_coord_diff = (72.475-abs(atom2[1] - atom1[1])) if abs(atom2[1] - atom1[1])>36.2375 else (atom2[1] - atom1[1])
        
# z_coord_diff = atom2[2] - atom1[2]

# euclidean_distance = np.sqrt(np.square(x_coord_diff) + np.square(y_coord_diff) + np.square(z_coord_diff))
# euclidean_distance
